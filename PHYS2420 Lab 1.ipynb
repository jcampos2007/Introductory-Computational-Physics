# %% [markdown]
# # **Goal**
#
#
# ---
#
# We'll be using Python extensively in this course and next semester. The goal of the labs are two fold:
#
# 1. Help you gain familarity and comfort with using Python to do scientific computing.
#
# 2. Learn to formulate physics problesm in a way that can be modeled by a computer and then write a program that does so.
#
# ---
# Today we will learn about some concepts we'll be using throughout the course(s) and doing a simulation of a problem that can be addressed using the momentum principle we discussed in class.
#
# ---
#
# Parts of this lab are based on work done by:  Ruth Chabay, James Munteanu, Aaron Titus, Bruce Sherwood, Raúl Morales Juberias, Ryan Norris
#
# ----

# %% [markdown]
# # Section 1. Variables (based on lessons from Python Numerical Methods)
#
# Variables allow us to store information. Values are assigned to a variable using "=". So for example x=2 takes the value 2 and assigns that value to the variable with the name "x". Unless that value is changed or the variable is deleted, the character "x" will behave like the value 2.

# %%
x = 2
print(x) #note this function outputs the value associated with a variable
# Out:
# 2

# %% [markdown]
# Try it yourself! Assign the value 4 to the variable y. Multiply by 6 to show that it behaves like the value 4.

# %%
#put your code here
y = 4
y *= 6
print(y) #yup, this is 24
# Out:
# 24

# %% [markdown]
# Note that values must always to the right of a variable. Python reads from right to left. So 2=x will not work but x=2 does.
#
# Variables in python can only contain alphanumeric characters and underscores (note that some languages like Julia permit unicode names). But the first character must be a letter or underscore. Spaces are not permitted in variable names and they are case sensitive.
#
# One useful tip is to choose names that can easily be associated with its role in a program. Using comments can also help make it clear what the variable is. In fact COMMENTS ARE EXPECTED in code you submit for this course.

# %%
#example (this is a comment)
r_0 = 3 # initial position, m

# %% [markdown]
# **Be Careful, you can accidentally overwrite functions that have the name you assign to a variable!!!!**
# so for example help=2 would overwrite the help function. Do not do this.
#
#
# ---
# There are various data structures in Python. We talked about some in lecture.
#
#
# 1.   Float
# 2.   Int
# 3.   Complex
#
#
# There are also booleen, string, lists, tuples, sets, and dictionaries. But mostly we'll be using NumPy Arrays.
#
#
# For today we'll stick with NumPy Arrays.
#
# Recall that we can import numpy with

# %%
import numpy as np

# %% [markdown]
# The assignment of np is just a common convention. I suppose you could choose anything else, but it's best to stick with that because people are used to it and it makes your code friendly to others reading it.
#
# If we want to make different arrays we can use

# %%
x = np.array([1,2,3])
y = np.array([[2, 3, 4], [5,6,7]])

# %% [markdown]
# Where we made the arrays
#
# $x=\big(1,2,3\big)$
#
# $y = \begin{pmatrix} 2&3&4\\5&6&7\end{pmatrix}$
#
# Note the [[ and ]] for the second declaration!
#
# There are some other useful ways to create an array. For example, what if we wanted to make an array from 0 to 10 with increments of 2?

# %%
a = np.arange(0,10,2)
print(a)
# Out:
# [0 2 4 6 8]

# %% [markdown]
# If we care specifically about the numberr of elements in addition to the start and end and also want them evenly spaced? We can use this:

# %%
b = np.linspace(0,10,8)
print(b)
# Out:
# [ 0.      1.4286  2.8571  4.2857  5.7143  7.1429  8.5714 10.    ]

# %% [markdown]
# We can access elements in our array using something like a[1]. Note that indexing starts at 0 in Python, so the last index is  N-1  where N is the total number of elements.

# %%
print(a[1])
print(a[6])

# %% [markdown]
# See the error?
#
# For 2D arrays you need to consider rows and columns. It goes row, column. So for example for 2D array y which we created above:

# %%
print(y[0,1]) #first row, second column

# %% [markdown]
# A trick is getting the last element. You can use also work backwards. x[-1] will give the last element in x. Give it a try.

# %%
print(x[-1])

# %% [markdown]
# Sometimes we want to predefine arrays. We can use np.zeros, np.empty, np.ones as three options. Note that np.empty doesn't really make an empty array it just fills it with very small numbers. Give these a try on your own, for example
#
# a=np.zeros(3)

# %% [markdown]
# You can also reassign values to elements in arrays. For example x[2] = 7 would replace the third element of x with the integer 7. You can even do that for more than one element using : notation. So x[:3]=2 would make the 1st->4th element 1.
#
#
# ---
#
#
# So the really special thing about NumPy arrays is that we cand do math operations to them. Note that powers in python are done using **

# %%
print(a)
print(a*2)
print(a**2) # this is squaring the values in a

# %% [markdown]
# We can even operate between arrays but they need to be the same shape.

# %%
print(a)
c=a*2
print(c)
print(a+c)
print(a/c)
#note that python doesn't like dividing by zero

# %% [markdown]
# You can also do logical statements on arrays

# %%
print(a)
print(a>2)

# %% [markdown]
# # Section 2. Iteration  (based on lessons from Python Numerical Methods)
#
# ---
#
# There are two main methods for iterating we'll use in this course. For-loops and while-loops.
#
#
# ---
#
#
# for-loops are repeated (iterated) for every value in a squence. They look like

# %%
# don't run this code it won't work
for looping variable in sequence:
    do this stuff

# %% [markdown]
# For example, if you wanted to print the squares of the first four integers from 1 to 5 how would you do this?
#
# It would look like the code below

# %%
for i in range(1,6):
  print(i**2)

# %% [markdown]
# Or if you wanted to use numpy arrays (not needed here)

# %%
for i in np.linspace(1,5,5):
  print(i**2) #notes linspace makes floats

# %% [markdown]
# while-loops are instructions that are repeated so long as the logical expression associated with it is true.

# %%
# don't run this it won't work
while logical expression:
  do this stuff

# %%
i=0
n=8
while i<=8:
  print(i)
  i=i+1

# %% [markdown]
# **BE CAREFUL YOU CAN MAKE AN INFINTE LOOP IF THE EXPRESSION IS ALWAYS TRUE**

# %% [markdown]
# # Plotting with matplotlib
#
#
# ---
#
# Data visualization and plotting is a huge task and we'll get more into as we progress. But for now, we are going to simply introduce a common plotting library, matplotlib.
# Typically if we want to do 2d plots, we can do

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Then if we want to make a plot, we can use a command like

# %%
x =np.arange(0,10,5)
y=x**2
plt.plot(x,y)
plt.show()

# %% [markdown]
# We can also get a little fancy by changing the color and plotting symbol. You can look these up on the documentation or in the book I'll link to the class notes (for some but not all options). But for example, plotting the above with cyan dots would be.

# %%
x =np.arange(0,10,5)
y=x**2
plt.plot(x,y,'c:')
plt.show()

# %% [markdown]
# You can overplot too, and this is when different colors and/or symbols is nice

# %%
x =np.arange(0,10,5)
y=x**2
z=np.sqrt(x)
plt.plot(x,y,'c:')
plt.plot(x,z)
plt.show()

# %% [markdown]
# Of course plots should have titles and can be different sizes and should have axis labeled and have legends. We can add a grid and even the plotting limits. So here is a better example.

# %%
plt.figure(figsize = (10,6))

x = np.linspace(5,15,10)
plt.plot(x, x**2, label = 'y=x^2')
plt.plot(x, x*2, 'r*', label = 'y=x*2')
plt.title('My first plot')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.xlim(5,15)
plt.ylim(0,200)
plt.grid()
plt.legend(loc = 2)
plt.show()

# %% [markdown]
# There are a variety of plots you can make. Here are some examples from the textbook Python Numerical Methods

# %%
x = np.arange(11)
y = x**2

plt.figure(figsize = (14, 8))

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.title('Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

plt.subplot(2, 3, 2)
plt.scatter(x,y)
plt.title('Scatter')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

plt.subplot(2, 3, 3)
plt.bar(x,y)
plt.title('Bar')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

plt.subplot(2, 3, 4)
plt.loglog(x,y)
plt.title('Loglog')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(which='both')

plt.subplot(2, 3, 5)
plt.semilogx(x,y)
plt.title('Semilogx')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(which='both')

plt.subplot(2, 3, 6)
plt.semilogy(x,y)
plt.title('Semilogy')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid()

plt.tight_layout()

plt.show()

# %% [markdown]
# You can save with plt.savefig.
#
# If you do that here, in colab, you can find the file on the left in 'sample data' unless otherwise specified. This will make it easier to download. There are other ways like mounting your google drive but for now, this is the simplest.

# %%
plt.figure(figsize = (8,6))
plt.plot(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.savefig('image.pdf')

# %% [markdown]
# # Now for an example problem
#
# Let's model a ball being kicked from the ground at rest using the momentum principle. Ignore air resistance. We will model it on Earth where g=9.81 m/s^2 and on the Moon where g=1.63 m/s^2.
#
# Before you get started, think about what you need to do. Remember the parts are
#
# 1. import
#
# What do you need to import?
#
# 2. Define constants
#
# What are the constants?
#
# 3. Define variables.
#
# What are the varibles?
#
#
# Also think about these questions and include these in the discussion portion of your lab report.
#
# 1. What differences do you expect in the behavior of the momentum, velocity, and position for the ball on the Earth vs the Moon?
# 2. What would happen if we included air resistance?
#
# To help you get started, I've shared a skeleton below, with comments where you need to fill in the missing parts or make a choice.
#
# Remember the algorithm from class is
#
# 1. Use net force to update momentum using the momentum principle.
# 2. Use the new momentum to find the velocity.
# 3. Use the new velocity to find the new position.
# 4. Make sure you update momentum also.
# 5. Depending on how you are iterating, you may need to update something like time or another variable.
#
# Feel free to change variable names.
#
# Make three graphs. Overplot Earth and Moon on them. You may need to think about axis bounds if they don't look good.
# 1. Momentum vs. Time
# 2. Velocity vs. Time
# 3. Position vs. Time
#
#
# Also answer these questions in your lab report.
#
# 1. Were you correct about your expectations in the differences between the graphs?
# 2. What did you observe?
# 3. What would happen if we made this same model for Jupiter?

# %%
# Import the necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# --------------------------------------------------------------------------
# PART 1: SETUP THE PHYSICS PROBLEM AND VARIABLES
# --------------------------------------------------------------------------

# Define the properties of our object and environment.
mass = 8                # Mass of the ball in kg
g = 9.81               # Gravitational acceleration (m/s^2)

# The net force on the ball is the force of gravity (F = mg).
# Since it's constant, we can calculate it once here.
F_net = -mass*g
# Define the initial conditions for the simulation.
initial_position = 20   # m
initial_velocity = 50   # m/s
initial_momentum = initial_velocity*mass

# Define the simulation time parameters.
total_time = 10         # seconds
dt = 0.01                # The time step (delta t) in seconds.
num_steps = int(total_time / dt)

# --------------------------------------------------------------------------
# PART 2: SETTING UP WITH NUMPY ARRAYS
# --------------------------------------------------------------------------

# We create arrays to store the results from every step of our simulation.
# Calculate the total number of steps we'll need.  #NOTE This should be an integer.
time = [0 for x in range(num_steps)]
momentum = [0 for x in range(num_steps)]
velocity = [0 for x in range(num_steps)]
position = [0 for x in range(num_steps)]
momentum[0] = initial_momentum
velocity[0] = initial_velocity
position[0] = initial_position
# Create arrays to hold our data.
#Think about what arrays you need.

# Set the initial values (at time = 0) for our arrays.

# --------------------------------------------------------------------------
# PART 3: THE SIMULATION LOOP
# --------------------------------------------------------------------------
# This loop is the core of our simulation. It steps through time and applies
# our physics rule at each step to predict the next state.

#Here is one way of doing it...There are other ways.

for i in range(1, num_steps):
  time[i] = i*dt
  momentum[i] = momentum[i-1] + (F_net * dt)
  velocity[i] = (momentum[i])/mass
  position[i] = position[i-1] + (velocity[i] * dt)


    #Use our algorithm here. Be sure to update the arrays.
    #Hint because we are plotting we need to update elements in the array.

print("Simulation complete!")
print(f"Calculated {len(time)} data points.")


# --------------------------------------------------------------------------
# PART 4: GRAPHING OUR RESULTS
# --------------------------------------------------------------------------
# Now we visualize the data we collected in our arrays.
# Overplot Earth and Moon.
# --- Graph 1: Momentum vs. Time ---
plt.subplot(3, 1, 1)
plt.plot(time,momentum)
plt.xlabel('Time')
plt.ylabel('Momentum')
plt.grid()
# ---

# --- Graph 2: Velocity vs. Time ---
plt.subplot(3, 1, 2)
plt.plot(time,velocity)
plt.xlabel('Time')
plt.ylabel('Velocity')
plt.grid()
# --- Graph 3: Position vs. Time ---
plt.subplot(3, 1, 3)
plt.plot(time,position)
plt.xlabel('Time')
plt.ylabel('Position')
plt.grid()
# Out:
# Simulation complete!
# Calculated 1000 data points.
