# %%
# Problem 7

m = 3 #kg
vx = [5, -2, 10, -8] #m/s
p = 0 #kg m/s

for v in vx:
  p += m*v

print("Total momentum of the system:", p, "kg m/s")
# Out:
# Total momentum of the system: 15 kg m/s

# %%
# Problem 8

def inelasticCollision(m1, v1, m2, v2):
  return ((m1*v1)+(m2*v2))/(m1+m2)

# %%
# Problem 9

import matplotlib.pyplot as plt

t = [0,1,2,3,4,5] #s
x = [0,15,30,45,60,75] #m

plt.plot(t,x)
plt.xlabel("Time (s)")
plt.ylabel("Position (m)")

plt.show()
